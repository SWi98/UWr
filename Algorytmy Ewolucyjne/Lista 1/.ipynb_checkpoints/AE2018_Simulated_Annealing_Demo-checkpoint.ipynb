# %% [markdown]
# # Simulated Annealing Demo
#
# Skrypt przedstawia przykładową implementację algorytmu symulowanego wyżarzania (ang. Simulated Annealing, SA) i jego zastosowanie do rozwiązywania problemu Quadratic Assignment Problem (QAP). Problem jest dokładnie opisany m.in. w pracy Burkarda i innych [1]. Popularne instancje problemu QAP można znaleźć w bibliotece QAPLib [2]. Skrypt skupia się na rozwiązywaniu instancji NUG12 [3], w celu rozwiązywania innych instancji może okazać się konieczna zmiana ustawień parametrów algorytmu.
#
# Literatura:
#
# [1]  Burkard, R., Cela, E., Pardalos, P., Pitsoulis, L., "The Quadratic Assignment Problem", http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.217.1914
#
# [2] QAPLIB, http://anjos.mgi.polymtl.ca/qaplib/
#
# [3] NUG12, http://anjos.mgi.polymtl.ca/qaplib/data.d/nug12.dat

# %% [raw]
# # Popularne instancje QAP wraz z dokładnym minimum funkcji celu
#    Nug12   12    578 (OPT)    (12,7,9,3,4,8,11,1,5,6,10,2)
#    Nug14   14   1014 (OPT)    (9,8,13,2,1,11,7,14,3,4,12,5,6,10)
#    Nug15   15   1150 (OPT)    (1,2,13,8,9,4,3,14,7,11,10,15,6,5,12)
#    Nug16a  16   1610 (OPT)    (9,14,2,15,16,3,10,12,8,11,6,5,7,1,4,13)
#    Nug16b  16   1240 (OPT)    (16,12,13,8,4,2,9,11,15,10,7,3,14,6,1,5)
#    Nug17   17   1732 (OPT)    (16,15,2,14,9,11,8,12,10,3,4,1,7,6,13,17,5)
#    Nug18   18   1930 (OPT)    (10,3,14,2,18,6,7,12,15,4,5,1,11,8,17,13,9,16)
#    Nug20   20   2570 (OPT)    (18,14,10,3,9,4,2,12,11,16,19,15,20,8,13,17,5,7,1,6)
#    Nug21   21   2438 (OPT)    (4,21,3,9,13,2,5,14,18,11,16,10,6,15,20,19,8,7,1,12,17)
#    Nug22   22   3596 (OPT)    (2,21,9,10,7,3,1,19,8,20,17,5,13,6,12,16,11,22,18,14,15)
#    Nug24   24   3488 (OPT)    (17,8,11,23,4,20,15,19,22,18,3,14,1,10,7,9,16,21,24,12,6,13,5,2)
#    Nug25   25   3744 (OPT)    (5,11,20,15,22,2,25,8,9,1,18,16,3,6,19,24,21,14,7,10,17,12,4,23,13)
# *  Nug27   27   5234 (OPT)    (23,18,3,1,27,17,5,12,7,15,4,26,8,19,20,2,24,21,14,10,9,13,22,25,6,16,11)
# *  Nug28   28   5166 (OPT)    (18,21,9,1,28,20,11,3,13,12,10,19,14,22,15,2,25,16,4,23,7,17,24,26,5,27,8,6)
# *  Nug30   30   6124 (OPT)    (5 12 6 13 2 21 26 24 10 9 29 28 17 1 8 7 19 25 23 22 11 16 30 4 15 18 27 3 14 20)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import urllib.request
from tqdm.auto import tqdm

# %matplotlib inline

# %%
QAP_INSTANCE_URL = f'http://anjos.mgi.polymtl.ca/qaplib/data.d/nug30.dat'
print(QAP_INSTANCE_URL)
# Out:
# http://anjos.mgi.polymtl.ca/qaplib/data.d/nug30.dat

# %% [markdown]
# ## Reading input data

# %%
def read(problem):
    global n, A, B
    QAP_INSTANCE_URL = f'http://anjos.mgi.polymtl.ca/qaplib/data.d/{problem}.dat'
    qap_instance_file = urllib.request.urlopen(QAP_INSTANCE_URL)

    line = qap_instance_file.readline()
    n = int(line.decode()[:-1].split()[0])
    #print('Problem size: %d' % n)

    A = np.empty((n, n))
    qap_instance_file.readline()
    for i in range(n):
        line = qap_instance_file.readline()
        A[i, :] = list(map(int, line.decode()[:-1].split()))
    #print('Flow matrix:\n', A)

    B = np.empty((n, n))
    qap_instance_file.readline()
    for i in range(n):
        line = qap_instance_file.readline()
        B[i, :] = list(map(int, line.decode()[:-1].split()))
    #print('Distance matrix:\n', B)

# %% [markdown]
# ## Objective function

# %%
def qap_objective_function(p):
    s = 0.0
    for i in range(n):
        s += (A[i, :] * B[p[i], p]).sum()
    return s

# %%
p = [11, 6, 8, 2, 3, 7, 10, 0, 4, 5, 9, 1]
print(qap_objective_function(p), p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-230-1904b1159d4e> in <module>
#       1 p = [11, 6, 8, 2, 3, 7, 10, 0, 4, 5, 9, 1]
# ----> 2 print(qap_objective_function(p), p)
#
# <ipython-input-229-4319cc1b9b9a> in qap_objective_function(p)
#       2     s = 0.0
#       3     for i in range(n):
# ----> 4         s += (A[i, :] * B[p[i], p]).sum()
#       5     return s
#
# ValueError: operands could not be broadcast together with shapes (25,) (12,)

# %% [markdown]
# ## Random Sampling

# %%
t0 = time.time()

T = 1000000

permutations = np.empty((T, n), dtype=np.int64)
costs = np.zeros(T)
for i in range(T):
    permutations[i, :] = np.random.permutation(n)
    costs[i] = qap_objective_function(permutations[i, :])

print(time.time() - t0)

p = permutations[costs.argmin(), :]
print(qap_objective_function(p), p)
# Out:
# 87.08107042312622
# 586.0 [ 4  3  7 11  5 10  6  8  9  1  0  2]

# %%
plt.figure()
plt.hist(costs, bins=100)
plt.show()

print(costs.mean(), costs.std())
# Out:
# 811.921768 49.7013396173

# %%
iterations = 10
costs = np.zeros(iterations)
read("nug24")
for i in tqdm(range(10)):
    costs[i] = SA(10000, 100, 0.999984, 1)[1]
    print(costs[i])
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 4014.0
# 4074.0
# 4014.0
# 4044.0
# 3934.0
# 4036.0
# 4030.0
# 3918.0
# 4006.0
# 3978.0

# %%
plt.figure()
plt.hist(costs)
plt.show()

print(costs.mean(), costs.std())
# Out:
# 4004.8 46.22726468221973

# %% [markdown]
# ## Simulated Annealing

# %%
def random_neighbor(p, radius):
    q = p.copy()
    for r in range(radius):
        i, j = np.random.choice(n, 2, replace=False)
        q[i], q[j] = q[j], q[i]
    return q, np.abs(i - j)

# %%
def basicSA(T, radius, alpha):

    t0 = time.time()

    p = np.random.permutation(n)
    p_cost = qap_objective_function(p)
    costs = np.zeros(T)
    for t in range(T):
        q, diff = random_neighbor(p, radius)
        q_cost = qap_objective_function(q)
        if(q_cost < p_cost):
            p, p_cost = q, q_cost
        elif(np.random.rand() < np.exp(- alpha * (q_cost - p_cost) * t/T)):
            p, p_cost = q, q_cost
        costs[t] = p_cost

    return (time.time() - t0, costs.min())

# %%
for (index, problem) in tqdm(enumerate(problems)):
    read(problem)
    print(f"\n{problem}\n")
    for i in range(10):
        solution = basicSA(T, 1, 1.0)
        print(f"Result: {solution[1]}. Optimum solution: {optimal_solutions[index]}. "
         +f"Difference: {optimal_solutions[index] - solution[1]}")
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Nug12
#
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 582.0. Optimum solution: 578. Difference: -4.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
#
# Nug14
#
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1018.0. Optimum solution: 1014. Difference: -4.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1016.0. Optimum solution: 1014. Difference: -2.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1016.0. Optimum solution: 1014. Difference: -2.0
# Result: 1016.0. Optimum solution: 1014. Difference: -2.0
# Result: 1016.0. Optimum solution: 1014. Difference: -2.0
#
# Nug15
#
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1152.0. Optimum solution: 1150. Difference: -2.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1152.0. Optimum solution: 1150. Difference: -2.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1152.0. Optimum solution: 1150. Difference: -2.0
#
# Nug16a
#
# Result: 1622.0. Optimum solution: 1610. Difference: -12.0
# Result: 1626.0. Optimum solution: 1610. Difference: -16.0
# Result: 1610.0. Optimum solution: 1610. Difference: 0.0
# Result: 1610.0. Optimum solution: 1610. Difference: 0.0
# Result: 1622.0. Optimum solution: 1610. Difference: -12.0
# Result: 1610.0. Optimum solution: 1610. Difference: 0.0
# Result: 1610.0. Optimum solution: 1610. Difference: 0.0
# Result: 1622.0. Optimum solution: 1610. Difference: -12.0
# Result: 1634.0. Optimum solution: 1610. Difference: -24.0
# Result: 1622.0. Optimum solution: 1610. Difference: -12.0
#
# Nug16b
#
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
#
# Nug17
#
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
# Result: 1742.0. Optimum solution: 1732. Difference: -10.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
# Result: 1742.0. Optimum solution: 1732. Difference: -10.0
# Result: 1742.0. Optimum solution: 1732. Difference: -10.0
# Result: 1732.0. Optimum solution: 1732. Difference: 0.0
# Result: 1732.0. Optimum solution: 1732. Difference: 0.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
#
# Nug18
#
# Result: 1944.0. Optimum solution: 1930. Difference: -14.0
# Result: 1936.0. Optimum solution: 1930. Difference: -6.0
# Result: 1944.0. Optimum solution: 1930. Difference: -14.0
# Result: 1930.0. Optimum solution: 1930. Difference: 0.0
# Result: 1930.0. Optimum solution: 1930. Difference: 0.0
# Result: 1946.0. Optimum solution: 1930. Difference: -16.0
# Result: 1954.0. Optimum solution: 1930. Difference: -24.0
# Result: 1944.0. Optimum solution: 1930. Difference: -14.0
# Result: 1938.0. Optimum solution: 1930. Difference: -8.0
# Result: 1938.0. Optimum solution: 1930. Difference: -8.0
#
# Nug20
#
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2574.0. Optimum solution: 2570. Difference: -4.0
# Result: 2588.0. Optimum solution: 2570. Difference: -18.0
# Result: 2588.0. Optimum solution: 2570. Difference: -18.0
# Result: 2602.0. Optimum solution: 2570. Difference: -32.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2574.0. Optimum solution: 2570. Difference: -4.0
# Result: 2596.0. Optimum solution: 2570. Difference: -26.0
# Result: 2574.0. Optimum solution: 2570. Difference: -4.0
# Result: 2574.0. Optimum solution: 2570. Difference: -4.0
#
# Nug21
#
# Result: 2438.0. Optimum solution: 2438. Difference: 0.0
# Result: 2442.0. Optimum solution: 2438. Difference: -4.0
# Result: 2438.0. Optimum solution: 2438. Difference: 0.0
# Result: 2438.0. Optimum solution: 2438. Difference: 0.0
# Result: 2438.0. Optimum solution: 2438. Difference: 0.0
# Result: 2438.0. Optimum solution: 2438. Difference: 0.0
# Result: 2442.0. Optimum solution: 2438. Difference: -4.0
# Result: 2460.0. Optimum solution: 2438. Difference: -22.0
# Result: 2462.0. Optimum solution: 2438. Difference: -24.0
# Result: 2442.0. Optimum solution: 2438. Difference: -4.0
#
# Nug22
#
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3604.0. Optimum solution: 3596. Difference: -8.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3644.0. Optimum solution: 3596. Difference: -48.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
#
# Nug24
#
# Result: 3506.0. Optimum solution: 3488. Difference: -18.0
# Result: 3510.0. Optimum solution: 3488. Difference: -22.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3514.0. Optimum solution: 3488. Difference: -26.0
# Result: 3524.0. Optimum solution: 3488. Difference: -36.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3524.0. Optimum solution: 3488. Difference: -36.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3558.0. Optimum solution: 3488. Difference: -70.0
#
# Nug25
#
# Result: 3748.0. Optimum solution: 3744. Difference: -4.0
# Result: 3748.0. Optimum solution: 3744. Difference: -4.0
# Result: 3750.0. Optimum solution: 3744. Difference: -6.0
# Result: 3744.0. Optimum solution: 3744. Difference: 0.0
# Result: 3750.0. Optimum solution: 3744. Difference: -6.0
# Result: 3746.0. Optimum solution: 3744. Difference: -2.0
# Result: 3768.0. Optimum solution: 3744. Difference: -24.0
# Result: 3744.0. Optimum solution: 3744. Difference: 0.0
# Result: 3764.0. Optimum solution: 3744. Difference: -20.0
# Result: 3744.0. Optimum solution: 3744. Difference: 0.0
#
# Nug27
#
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5278.0. Optimum solution: 5234. Difference: -44.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5278.0. Optimum solution: 5234. Difference: -44.0
#
# Nug28
#
# Result: 5278.0. Optimum solution: 5166. Difference: -112.0
# Result: 5216.0. Optimum solution: 5166. Difference: -50.0
# Result: 5186.0. Optimum solution: 5166. Difference: -20.0
# Result: 5192.0. Optimum solution: 5166. Difference: -26.0
# Result: 5192.0. Optimum solution: 5166. Difference: -26.0
# Result: 5182.0. Optimum solution: 5166. Difference: -16.0
# Result: 5218.0. Optimum solution: 5166. Difference: -52.0
# Result: 5166.0. Optimum solution: 5166. Difference: 0.0
# Result: 5200.0. Optimum solution: 5166. Difference: -34.0
# Result: 5194.0. Optimum solution: 5166. Difference: -28.0

# %%
T = 500000
for (index, problem) in tqdm(enumerate(problems)):
    read(problem)
    print(f"\n{problem}\n")
    for i in range(10):
        solution = basicSA(T, 1, 0.01)
        print(f"Result: {solution[1]}. Optimum solution: {optimal_solutions[index]}. "
         +f"Difference: {optimal_solutions[index] - solution[1]}")
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Nug12
#
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
#
# Nug14
#
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1016.0. Optimum solution: 1014. Difference: -2.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
#
# Nug15
#
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1152.0. Optimum solution: 1150. Difference: -2.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
#
# Nug16b
#
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
#
# Nug17
#
# Result: 1732.0. Optimum solution: 1732. Difference: 0.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
# Result: 1736.0. Optimum solution: 1732. Difference: -4.0
# Result: 1732.0. Optimum solution: 1732. Difference: 0.0
# Result: 1742.0. Optimum solution: 1732. Difference: -10.0
# Result: 1732.0. Optimum solution: 1732. Difference: 0.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
# Result: 1736.0. Optimum solution: 1732. Difference: -4.0
# Result: 1732.0. Optimum solution: 1732. Difference: 0.0
# Result: 1732.0. Optimum solution: 1732. Difference: 0.0
#
# Nug18
#
# Result: 1946.0. Optimum solution: 1930. Difference: -16.0
# Result: 1936.0. Optimum solution: 1930. Difference: -6.0
# Result: 1930.0. Optimum solution: 1930. Difference: 0.0
# Result: 1946.0. Optimum solution: 1930. Difference: -16.0
# Result: 1942.0. Optimum solution: 1930. Difference: -12.0
# Result: 1948.0. Optimum solution: 1930. Difference: -18.0
# Result: 1946.0. Optimum solution: 1930. Difference: -16.0
# Result: 1930.0. Optimum solution: 1930. Difference: 0.0
# Result: 1930.0. Optimum solution: 1930. Difference: 0.0
# Result: 1930.0. Optimum solution: 1930. Difference: 0.0
#
# Nug20
#
# Result: 2598.0. Optimum solution: 2570. Difference: -28.0
# Result: 2574.0. Optimum solution: 2570. Difference: -4.0
# Result: 2586.0. Optimum solution: 2570. Difference: -16.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2574.0. Optimum solution: 2570. Difference: -4.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2578.0. Optimum solution: 2570. Difference: -8.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2574.0. Optimum solution: 2570. Difference: -4.0
#
# Nug21
#
# Result: 2446.0. Optimum solution: 2438. Difference: -8.0
# Result: 2438.0. Optimum solution: 2438. Difference: 0.0
# Result: 2442.0. Optimum solution: 2438. Difference: -4.0
# Result: 2442.0. Optimum solution: 2438. Difference: -4.0
# Result: 2442.0. Optimum solution: 2438. Difference: -4.0
# Result: 2454.0. Optimum solution: 2438. Difference: -16.0
# Result: 2452.0. Optimum solution: 2438. Difference: -14.0
# Result: 2442.0. Optimum solution: 2438. Difference: -4.0
# Result: 2438.0. Optimum solution: 2438. Difference: 0.0
# Result: 2444.0. Optimum solution: 2438. Difference: -6.0
#
# Nug22
#
# Result: 3600.0. Optimum solution: 3596. Difference: -4.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3600.0. Optimum solution: 3596. Difference: -4.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3602.0. Optimum solution: 3596. Difference: -6.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3602.0. Optimum solution: 3596. Difference: -6.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
#
# Nug24
#
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3496.0. Optimum solution: 3488. Difference: -8.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3520.0. Optimum solution: 3488. Difference: -32.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3498.0. Optimum solution: 3488. Difference: -10.0
# Result: 3508.0. Optimum solution: 3488. Difference: -20.0
# Result: 3500.0. Optimum solution: 3488. Difference: -12.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
#
# Nug25
#
# Result: 3750.0. Optimum solution: 3744. Difference: -6.0
# Result: 3756.0. Optimum solution: 3744. Difference: -12.0
# Result: 3746.0. Optimum solution: 3744. Difference: -2.0
# Result: 3748.0. Optimum solution: 3744. Difference: -4.0
# Result: 3748.0. Optimum solution: 3744. Difference: -4.0
# Result: 3748.0. Optimum solution: 3744. Difference: -4.0
# Result: 3752.0. Optimum solution: 3744. Difference: -8.0
# Result: 3750.0. Optimum solution: 3744. Difference: -6.0
# Result: 3748.0. Optimum solution: 3744. Difference: -4.0
# Result: 3746.0. Optimum solution: 3744. Difference: -2.0
#
# Nug27
#
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5236.0. Optimum solution: 5234. Difference: -2.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5324.0. Optimum solution: 5234. Difference: -90.0
# Result: 5290.0. Optimum solution: 5234. Difference: -56.0
# Result: 5238.0. Optimum solution: 5234. Difference: -4.0
#
# Nug28
#
# Result: 5172.0. Optimum solution: 5166. Difference: -6.0
# Result: 5222.0. Optimum solution: 5166. Difference: -56.0
# Result: 5200.0. Optimum solution: 5166. Difference: -34.0
# Result: 5172.0. Optimum solution: 5166. Difference: -6.0
# Result: 5166.0. Optimum solution: 5166. Difference: 0.0
# Result: 5216.0. Optimum solution: 5166. Difference: -50.0
# Result: 5220.0. Optimum solution: 5166. Difference: -54.0
# Result: 5178.0. Optimum solution: 5166. Difference: -12.0
# Result: 5186.0. Optimum solution: 5166. Difference: -20.0
# Result: 5212.0. Optimum solution: 5166. Difference: -46.0

# %%
def do_test(problem, optimal_solution):
    print(f"Solving {problem}")
    print(f"Optimal solution: {optimal_solution}")
    read(problem)
    for i in np.arange(0.7, 1.1, 0.1):
        print(f"Alpha = {i}")
        basicSA(700000, 1, i)

# %%
do_test("nug25", 3744)
# Out:
# Solving nug25
# Optimal solution: 3744
# Alpha = 1
# 95.79679083824158 3744.0
# Alpha = 2
# 91.10629439353943 3758.0
# Alpha = 3
# 97.6995141506195 3750.0

# %%
datas = []

T = 500000
radius = 1
alpha = 1.0
temperature = 300
t0 = time.time()
t_change = 0.999984
p = np.random.permutation(n)
p_cost = qap_objective_function(p)
costs = np.zeros(T)
for t in tqdm(range(1)):
    q = random_neighbor(p, radius)
    q_cost = qap_objective_function(q)
    if(q_cost < p_cost):
        p, p_cost = q, q_cost
    elif(np.random.rand() < np.exp(-(q_cost - p_cost)/temperature)):
        p, p_cost = q, q_cost
    costs[t] = p_cost
    temperature = temperature * t_change
    if t%100000 == 0:
        print(temperature)
        

print(time.time() - t0, costs.min())
# Out:
# 16
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 299.9952
#
# 0.03388261795043945 0.0

# %%
def SA(T, temperature, t_change, radius):
    t0 = time.time()

    p = np.random.permutation(n)
    p_cost = qap_objective_function(p)
    costs = np.zeros(T)
    for t in range(T):
        q, diff = random_neighbor(p, radius)
        q_cost = qap_objective_function(q)
        if(q_cost < p_cost):
            p, p_cost = q, q_cost
        elif(np.random.rand() < np.exp(-(q_cost - p_cost)/temperature)):
            p, p_cost = q, q_cost
        costs[t] = p_cost
        temperature = temperature * t_change

    return(time.time() - t0, costs.min())

# %%
problems = ['Nug12','Nug14', 'Nug15', 'Nug16b', 'Nug17', 'Nug18', 'Nug20',
            'Nug21', 'Nug22', 'Nug24', 'Nug25', 'Nug27', 'Nug28']
optimal_solutions = [578, 1014, 1150, 1240, 1732, 1930, 2570, 
                     2438, 3596, 3488, 3744, 5234, 5166]

# %%
T = 500000
temperature = 300
t_change = 0.99999
radius = 1

# %% [markdown]
# ## Zadanie A/E

# %%
print(f"Solving for T = {T}, temp = {temperature}, t_change = {t_change}, radius = {radius}")
for (index, problem) in tqdm(enumerate(problems)):
    read(problem)
    print(f"\n{problem}\n")
    for i in range(10):
        solution = SA(T, temperature, t_change, radius)
        print(f"Result: {solution[1]}. Optimum solution: {optimal_solutions[index]}. "
         +f"Difference: {optimal_solutions[index] - solution[1]}")
# Out:
# Solving for T = 500000, temp = 300, t_change = 0.99999, radius = 1
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Nug12
#
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
# Result: 578.0. Optimum solution: 578. Difference: 0.0
#
# Nug14
#
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1016.0. Optimum solution: 1014. Difference: -2.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1018.0. Optimum solution: 1014. Difference: -4.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
# Result: 1014.0. Optimum solution: 1014. Difference: 0.0
#
# Nug15
#
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1152.0. Optimum solution: 1150. Difference: -2.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
# Result: 1150.0. Optimum solution: 1150. Difference: 0.0
#
# Nug16b
#
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
# Result: 1240.0. Optimum solution: 1240. Difference: 0.0
#
# Nug17
#
# Result: 1742.0. Optimum solution: 1732. Difference: -10.0
# Result: 1742.0. Optimum solution: 1732. Difference: -10.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
# Result: 1732.0. Optimum solution: 1732. Difference: 0.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
# Result: 1732.0. Optimum solution: 1732. Difference: 0.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
# Result: 1732.0. Optimum solution: 1732. Difference: 0.0
# Result: 1734.0. Optimum solution: 1732. Difference: -2.0
#
# Nug18
#
# Result: 1930.0. Optimum solution: 1930. Difference: 0.0
# Result: 1938.0. Optimum solution: 1930. Difference: -8.0
# Result: 1938.0. Optimum solution: 1930. Difference: -8.0
# Result: 1948.0. Optimum solution: 1930. Difference: -18.0
# Result: 1936.0. Optimum solution: 1930. Difference: -6.0
# Result: 1942.0. Optimum solution: 1930. Difference: -12.0
# Result: 1938.0. Optimum solution: 1930. Difference: -8.0
# Result: 1930.0. Optimum solution: 1930. Difference: 0.0
# Result: 1946.0. Optimum solution: 1930. Difference: -16.0
# Result: 1946.0. Optimum solution: 1930. Difference: -16.0
#
# Nug20
#
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2588.0. Optimum solution: 2570. Difference: -18.0
# Result: 2574.0. Optimum solution: 2570. Difference: -4.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2574.0. Optimum solution: 2570. Difference: -4.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
# Result: 2570.0. Optimum solution: 2570. Difference: 0.0
#
# Nug21
#
# Result: 2458.0. Optimum solution: 2438. Difference: -20.0
# Result: 2462.0. Optimum solution: 2438. Difference: -24.0
# Result: 2438.0. Optimum solution: 2438. Difference: 0.0
# Result: 2456.0. Optimum solution: 2438. Difference: -18.0
# Result: 2458.0. Optimum solution: 2438. Difference: -20.0
# Result: 2438.0. Optimum solution: 2438. Difference: 0.0
# Result: 2456.0. Optimum solution: 2438. Difference: -18.0
# Result: 2458.0. Optimum solution: 2438. Difference: -20.0
# Result: 2456.0. Optimum solution: 2438. Difference: -18.0
# Result: 2456.0. Optimum solution: 2438. Difference: -18.0
#
# Nug22
#
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3632.0. Optimum solution: 3596. Difference: -36.0
# Result: 3644.0. Optimum solution: 3596. Difference: -48.0
# Result: 3614.0. Optimum solution: 3596. Difference: -18.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3632.0. Optimum solution: 3596. Difference: -36.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
# Result: 3596.0. Optimum solution: 3596. Difference: 0.0
#
# Nug24
#
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3522.0. Optimum solution: 3488. Difference: -34.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3500.0. Optimum solution: 3488. Difference: -12.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
# Result: 3506.0. Optimum solution: 3488. Difference: -18.0
# Result: 3500.0. Optimum solution: 3488. Difference: -12.0
# Result: 3488.0. Optimum solution: 3488. Difference: 0.0
#
# Nug25
#
# Result: 3744.0. Optimum solution: 3744. Difference: 0.0
# Result: 3744.0. Optimum solution: 3744. Difference: 0.0
# Result: 3750.0. Optimum solution: 3744. Difference: -6.0
# Result: 3744.0. Optimum solution: 3744. Difference: 0.0
# Result: 3744.0. Optimum solution: 3744. Difference: 0.0
# Result: 3746.0. Optimum solution: 3744. Difference: -2.0
# Result: 3750.0. Optimum solution: 3744. Difference: -6.0
# Result: 3746.0. Optimum solution: 3744. Difference: -2.0
# Result: 3744.0. Optimum solution: 3744. Difference: 0.0
# Result: 3744.0. Optimum solution: 3744. Difference: 0.0
#
# Nug27
#
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5326.0. Optimum solution: 5234. Difference: -92.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5260.0. Optimum solution: 5234. Difference: -26.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5234.0. Optimum solution: 5234. Difference: 0.0
# Result: 5298.0. Optimum solution: 5234. Difference: -64.0
#
# Nug28
#
# Result: 5246.0. Optimum solution: 5166. Difference: -80.0
# Result: 5166.0. Optimum solution: 5166. Difference: 0.0
# Result: 5176.0. Optimum solution: 5166. Difference: -10.0
# Result: 5272.0. Optimum solution: 5166. Difference: -106.0
# Result: 5192.0. Optimum solution: 5166. Difference: -26.0
# Result: 5284.0. Optimum solution: 5166. Difference: -118.0
# Result: 5178.0. Optimum solution: 5166. Difference: -12.0
# Result: 5192.0. Optimum solution: 5166. Difference: -26.0
# Result: 5210.0. Optimum solution: 5166. Difference: -44.0
# Result: 5264.0. Optimum solution: 5166. Difference: -98.0

# %%
def temp_change(temp):
    return temp*0.99999

iter = 500000
t = np.zeros(iter)
t[0] = 500


for i in range(1, iter):
    t[i] = temp_change(t[i-1])
plt.figure(figsize=(26, 8), dpi = 300)
plt.plot(t)
plt.title("Temperature decline")
plt.show()

# %%
T = 500000
t = np.zeros(T+1)
t[1] = T/1
for i in range(1, T):
    t[2] = T/(i*1)

plt.figure(figsize=(26, 8), dpi = 300)
plt.plot(t)
plt.show()

# %% [markdown]
# ## Zadanie B

# %% [markdown]
# ### Histogram dla 1000 wywołań Nug15

# %%
iters = 500
results = np.zeros(500)
read('Nug15')
for i in tqdm(range(iters)):
    results[i] = SA(T, temperature, t_change, radius)[1]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=500.0), HTML(value='')))

# %%
iters = 500
results2 = np.zeros(500)
read('Nug15')
for i in tqdm(range(iters)):
    results2[i] = SA(T, temperature, t_change, radius)[1]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=500.0), HTML(value='')))

# %%
all_results = np.append(results, results2)

# %%
plt.figure()
plt.hist(all_results)
plt.show()

print(all_results.mean(), all_results.std())
# Out:
# 1150.45 0.8817596044274199

# %% [markdown]
# ## Zadanie C

# %%
def verboseSA(T, temperature, t_change, radius, basic = False):
    t0 = time.time()
    
    m = 1000
    successes = 0
    losses = 0
    draws = 0
    all_successes = np.zeros(int(T/m))
    all_losses = np.zeros(int(T/m))
    all_draws = np.zeros(int(T/m))
    p = np.random.permutation(n)
    p_cost = qap_objective_function(p)
    costs = np.zeros(T)
    differences = [[] for _ in range(n+1)]
    for t in range(T):
        q, diff = random_neighbor(p, radius)
        q_cost = qap_objective_function(q)
        if basic:
            cond = np.exp(- 1 * (q_cost - p_cost) * t/T)
        else:
            cond = np.exp(-(q_cost - p_cost)/temperature)
        if(q_cost < p_cost):
            differences[diff].append(p_cost - q_cost)
            p, p_cost = q, q_cost
            successes += 1
        elif np.random.rand() < cond:
            p, p_cost = q, q_cost
            losses += 1
        else:
            draws += 1
            
        costs[t] = p_cost
        temperature = temperature * t_change
        
        if((t+1)%m == 0):
            thousand = int((t+1)/m)
            all_successes[thousand-1] = successes
            all_losses[thousand-1] = losses
            all_draws[thousand-1] = draws
            successes = 0
            losses = 0
            draws = 0

    return(all_successes, all_losses, all_draws, differences)

# %%
read("nug17")
s1, l1, d1, dif1 = verboseSA(500000, 300,   0.999990, 1)
s2, l2, d2, dif2 = verboseSA(500000, 400,   0.99997, 1)
s3, l3, d3, dif3 = verboseSA(500000, 2000,  0.999985, 1)
s4, l4, d4, dif4 = verboseSA(500000, 3000,  0.999983, 1)
s5, l5, d5, dif5 = verboseSA(500000, 10000, 0.999980, 1)

# %%
plt.figure(figsize=(10, 5))
plt.title("Successes per thousand in nug17")
plt.plot(s1, label = "300, 0.99999")
plt.plot(s2, label = "400,   0.99995")
plt.plot(s3, label = "2000, 0.999985")
plt.plot(s4, label = "3000, 0.999984")
plt.plot(s5, label = "10000, 0.99998")
plt.xlabel("Thousand")
plt.ylabel("Total amount in one thousand")
plt.legend()

plt.show()
plt.figure(figsize=(10, 5))
plt.title("Losses per thousand in nug17")
plt.plot(l1, label = "300, 0.99999")
plt.plot(l2, label = "400,   0.99995")
plt.plot(l3, label = "2000, 0.999985")
plt.plot(l4, label = "3000, 0.999984")
plt.plot(l5, label = "10000, 0.99998")
plt.xlabel("Thousand")
plt.ylabel("Total amount in one thousand")
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.title("Draws per thousand in nug17")
plt.plot(d1, label = "300, 0.99999")
plt.plot(d2, label = "400,   0.99995")
plt.plot(d3, label = "2000, 0.999985")
plt.plot(d4, label = "3000, 0.999984")
plt.plot(d5, label = "10000, 0.99998")
plt.xlabel("Thousand")
plt.ylabel("Total amount in one thousand")
plt.legend()
plt.show()

# %% [markdown]
# ## Zadanie D

# %%
for e in [dif1, dif2, dif3, dif4, dif5]:
    xs = []
    ys = []
    for i in range(len(e)):
        ys += e[i]
        xs += [i for _ in range(len(e[i]))]
    plt.figure()
    plt.xlabel("Distance")
    plt.ylabel("Difference between states")
    plt.scatter(xs, ys, edgecolors = '#C0C0C0')

# %%
plt.figure()
plt.plot(all_results)
plt.show()
